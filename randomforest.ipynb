# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df=pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target']=y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.219035 -0.409850  0.760109 -1.600930 -0.997813       1
# 1 -1.159168 -2.864273  0.726972 -2.607814  1.055634       1
# 2 -1.020467  0.565512  0.866808 -0.026005  1.926857       0
# 3  0.358131 -1.684075  2.324901  1.826428  2.393520       0
# 4 -2.130748  0.395661 -0.174633 -2.142234 -2.587240       1

# %%
# randomly genrate 50% of row data
def sample_rows(df,percent):
    return df.sample(int(percent*df.shape[0]), replace=True)

# %%
def sample_features(df,percent):
    cols=random.sample(df.columns.tolist()[:1], int(percent*df.shape[1]))
    return df[cols]

# %%
def combined_sampling(df,row_percent,col_percent):
    new_df=sample_rows(df,row_percent)
    return sample_features(new_df,col_percent)

# %%
df1=sample_rows(df,0.2)

# %%
df2=sample_rows(df,0.2)

# %%
df3=sample_rows(df,0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()
clf2=DecisionTreeClassifier()
clf3=DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df1.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df1.iloc[:,-1])
# model trained
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.875, 'x[4] <= -0.482\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.25, 0.625, 'x[0] <= 0.524\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.375, 0.375, 'x[2] <= 1.058\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.625, 'x[3] <= -1.287\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.9, 'x[3] <= -1.259\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.25, 0.7, 'x[0] <= 0.307\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.375, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.7, 'x[0] <= -0.198\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.625, 0.8, '  False'),
#  Text(0.625, 0.5, 'x[3] <= 1.787\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.5, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.75, 0.3, 'x[4] <= 0.977\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.625, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.875, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.875, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5555555555555556, 0.9285714285714286, 'x[2] <= 0.363\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.4444444444444444, 0.7857142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.8571428571428572, 'True  '),
#  Text(0.6666666666666666, 0.7857142857142857, 'x[0] <= 0.823\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.6111111111111112, 0.8571428571428572, '  False'),
#  Text(0.5555555555555556, 0.6428571428571429, 'x[4] <= 1.949\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.4444444444444444, 0.5, 'x[2] <= 2.451\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.2222222222222222, 0.35714285714285715, 'x[0] <= -0.845\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.1111111111111111, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3333333333333333, 0.21428571428571427, 'x[0] <= -0.771\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
# ...

# %%
clf1.predict(np.array([-1.020467,	0.565512,	0.866808,	-0.026005,	1.926857]).reshape(1,5))
# Out:
# C:\Users\ANUJ\mlenv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-1.020467,	0.565512,	0.866808,	-0.026005,	1.926857]).reshape(1,5))
# Out:
# C:\Users\ANUJ\mlenv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.020467,	0.565512,	0.866808,	-0.026005,	1.926857]).reshape(1,5))
# Out:
# C:\Users\ANUJ\mlenv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 from sklearn.metrics import accuracy_score
# ----> 3 y_pred = clf.predict(X_test)
#       4 print(accuracy_score(y_test, y_pred))
#
# NameError: name 'clf' is not defined
